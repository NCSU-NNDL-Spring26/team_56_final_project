# %%
#Test data extraction and preprocessing steps.

# %%
from src.preprocess import load_record, extract_beats, normalize_beats

record_path = "../../data/data/MITBIHRawData/100"
record, annotation = load_record(record_path)

print(record.p_signal.shape)
print(len(annotation.sample))
print(annotation.symbol[:20])
# Out:
# (650000, 2)
# 2274
# ['+', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'A', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N']

# %%
X, y = extract_beats(record, annotation, window_size=200, channel=0)
X = normalize_beats(X)

print(X.shape)
print(y.shape)
# Out:
# (2271, 400)
# (2271,)

# %%
import matplotlib.pyplot as plt

plt.plot(X[0])
plt.title(f"Label: {y[0]}")
plt.show()

# %%
import numpy as np

unique, counts = np.unique(y, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {np.int64(0): np.int64(2237), np.int64(1): np.int64(33), np.int64(2): np.int64(1)}
